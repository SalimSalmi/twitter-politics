# %%
import getTermsImproved
import operator
import datetime
reload(getTermsImproved)
########
# Have to modify that 
# Should have incremental ints as keys as party names
# which are same as filenames as values
# partyNums = {0: "50p", 1: "cda", 2: "cu", 3:"d66", 4:"gl", 5:"pvda", 6:"pvdd", 7:"pvv", 8:"sgp", 9:"sp", 10:"vvd"}

# Doing this while I don't have access to pvv
partyNums = {0: "50p", 1: "cda", 2: "cu", 3:"d66", 4:"gl", 5:"pvda", 6:"pvdd", 7:"vvd", 8:"sgp", 9:"sp"}

########
########


allTerms = {}
idfs = {}


# Loop over every party
# Return a nested dict 
# Outer dict k: int, v: dict
# Inner dict k: term, v: frequency
for x in xrange(0,len(partyNums)):
    print "Started " + str(partyNums[x]) + " " + str(datetime.datetime.now())
    allTerms[x] = getTermsImproved.getTerms("/Users/user/Delft/IR/project/crawl/tutorial/res/1200/" + partyNums[x]+'.json')
    
    # Save all idfs into a dict of dicts
    # Outer dict k: int, v: dict
    # Inner dict k: term, v: present or not
    idfs[x] = {}
#     print len(allTerms[0])
    print "Finished " + str(partyNums[x]) + " " + str(datetime.datetime.now())
#     print datetime.datetime.now()
# Out:
# Started pvv 2017-04-05 17:38:45.398527
# Finished pvv 2017-04-05 17:39:37.351771

# %%
print sum([len(allTerms[x]) for x in range(7,8)])
# Out:
# 19106

# %%
# Get TFIDF for each term
# TF - how many times present in a domain - have that from top word count
# IDF - in how many domain is there that c
# Loop over every party
idfs[x] = {}

for x in xrange(len(allTerms)):
    print "Started " + str(partyNums[x]) + " " + str(datetime.datetime.now())
    # Loop over every word for the party
    for y in allTerms[x]:
        # initialise the count for the word
        idfs[x][y] = 0
        # Loop over every party in which the word could be
        for z in xrange(len(allTerms)):
        # If the term is present on a domain
        # Increment the count
            if y in allTerms[z]:
                idfs[x][y] += 1
    print "Finished " + str(partyNums[x]) + " " + str(datetime.datetime.now())
# Out:
# Started pvv 2017-04-05 17:42:36.212353
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-326b48df9a9e> in <module>()
#      15         # If the term is present on a domain
#      16         # Increment the count
# ---> 17             if y in allTerms[z]:
#      18                 idfs[x][y] += 1
#      19     print "Finished " + str(partyNums[x]) + " " + str(datetime.datetime.now())
#
# KeyError: 0

# %%
# Now that we have TFs from allTerms and IDFs get TFIDF
tfidf = {}
# For every party
for x in xrange(len(allTerms)):
    tfidf[x] = {};
    # For every word inside that party
    for y in allTerms[x]:
        tfidf[x][y] = float(allTerms[x][y])/idfs[x][y]
        # print y; print allTerms[x][y]; print idfs[x][y];print tfidf[x][y]

sorted_lists = {}
for x in xrange(len(tfidf)):
    sorted_lists[x] = sorted(tfidf[x].items(),key=operator.itemgetter(1), reverse = True);

# %%
# Set the number of terms shown per party
n = 100
for x in xrange(len(tfidf)):
	print "For party " + partyNums[x] + " the most unique terms based on tfidf are:"
	for y in xrange(n):
		print sorted_lists[x][y]
	print "\n"
# Out:
# For party 50p the most unique terms based on tfidf are:
# ('poen', 303.0)
# ('delen', 167.8)
# ('hoofdbestuur', 126.75)
# ('bericht', 110.2)
# ('homepagina', 74.0)
# ('mensen', 73.9)
# ('ouderen', 66.44444444444444)
# ('zoeken', 26.0)
# ('zoek', 25.6)
# ('tamara', 25.0)
# ('ontvang', 24.833333333333332)
# ('jij', 24.666666666666668)
# ('ockje', 24.0)
# ('rels', 24.0)
# ('gemenebest', 24.0)
# ('kandidaat', 23.22222222222222)
# ('gebruik', 23.2)
# ('miranda', 23.0)
# ('iedereen', 22.666666666666668)
# ('maakt', 22.4)
# ('jeugdbendes', 22.0)
# ('taverne', 22.0)
# ('vragen', 21.9)
# ('trainingen', 21.571428571428573)
# ('zevenbergen', 21.0)
# ('liber', 21.0)
# ('vrouwending', 21.0)
# ('dylan', 20.5)
# ('vind', 20.22222222222222)
# ('malik', 20.0)
# ('verschillende', 19.6)
# ('onderwerpen', 19.333333333333332)
# ('gaan', 19.3)
# ('hes', 18.0)
# ('azmani', 18.0)
# ('psychologisch', 18.0)
# ('lelykring', 18.0)
# ('denk', 17.88888888888889)
# ('eigen', 17.7)
# ('heel', 17.7)
# ('werk', 17.6)
# ('community', 17.6)
# ('recht', 17.5)
# ('meedoen', 17.444444444444443)
# ('daarom', 17.3)
# ('zit', 17.11111111111111)
# ('foort', 17.0)
# ('leven', 17.0)
#
#
# For party sgp the most unique terms based on tfidf are:
# ('sgpdinkel', 1094.0)
# ('autocampagne', 1090.0)
# ('sgp', 1017.5555555555555)
# ('banier', 831.0)
# ('casemanager', 600.0)
# ('eurofractie', 553.0)
# ('kleurwedstrijd', 545.0)
# ('doolaard', 428.0)
# ('sjon', 423.0)
# ('hpool', 409.0)
# ('sgpt', 408.0)
# ('doeleman', 408.0)
# ('wgoudriaan', 408.0)
# ('idejong', 408.0)
# ('goudriaan', 408.0)
# ('wdoeleman', 408.0)
# ('vormingdinkel', 407.0)
# ('kindzorg', 400.0)
# ('levensbreed', 400.0)
# ('langdurige', 292.6)
# ('mensen', 261.4)
# ('instituut', 250.44444444444446)
# ('secretariaat', 242.44444444444446)
# ('afdeling', 231.9)
# ('gebruiken', 225.5)
# ('lijkbezorging', 209.0)
# ('hbt', 204.5)
# ('wilhelm', 204.0)
# ('budgethouders', 200.0)
# ('zorgvormen', 200.0)
# ('zorgwetten', 200.0)
# ('onvrijwillige', 200.0)
# ('zorgaanbieder', 200.0)
# ('papierberg', 200.0)
# ('dementiezorg', 200.0)
# ('ingroeimodel', 200.0)
# ('werkwoord', 193.0)
# ('voorlichting', 191.6)
# ('gezichtenboek', 190.0)
# ('digibron', 190.0)
# ('toestaat', 185.5)
# ('meten', 185.5)
# ('huisstijl', 181.66666666666666)
# ('elijkheden', 181.0)
# ('huishou', 181.0)
# ('dossiers', 175.5)
# ('verder', 174.3)
# ('dementie', 160.0)
# ('budget', 160.0)
# ('versturen', 159.14285714285714)
# ('afdelingen', 153.2)
# ('partijbureau', 150.6)
# ('onderdelen', 144.75)
# ('anbi', 140.625)
# ('eenmalig', 139.125)
# ('optimale', 139.125)
# ('pool', 137.33333333333334)
# ('wedstrijd', 136.25)
# ('adviseur', 136.22222222222223)
# ('jongeren', 131.9)
# ('sociale', 131.6)
# ('ondernemers', 127.3)
# ('verklaring', 127.11111111111111)
# ('goede', 123.4)
# ('missie', 121.33333333333333)
# ('onze', 120.5)
# ('wet', 118.4)
# ('staan', 117.9)
# ('wanneer', 117.2)
# ('vragen', 116.7)
# ('bieden', 114.6)
# ('bestuur', 113.8)
# ('terug', 113.8)
# ('gebruikt', 111.8)
# ('zullen', 111.7)
# ('toe', 111.6)
# ('hoogte', 111.5)
# ('ontwikkelingen', 111.4)
# ('blijf', 111.4)
# ('sommige', 111.3)
# ('controle', 111.3)
# ('zichtbaar', 111.3)
# ('lokaal', 111.3)
# ('speerpunten', 110.1)
# ('administratie', 109.6)
# ('overzicht', 109.4)
# ('directie', 109.3)
# ('geschiedenis', 109.1)
# ('platform', 109.0)
# ('internationaal', 109.0)
# ('bijeenkomsten', 109.0)
# ('eindredacteur', 104.5)
# ('indicatie', 100.16666666666667)
# ('topkwaliteit', 100.0)
# ('zorgkantoor', 100.0)
# ('stoornis', 100.0)
# ('eenverdiener', 96.5)
# ('awbz', 86.33333333333333)
# ('eigen', 84.8)
# ('krijgen', 83.3)
#
#
# For party sp the most unique terms based on tfidf are:
# ('goubet', 1425.0)
# ('weert', 1037.4)
# ('mensenbestuur', 775.0)
# ('lichtenberg', 774.0)
# ('weerter', 639.0)
# ('hierhome', 420.5)
# ('nederweert', 407.5)
# ('commonsbnd', 387.0)
# ('leudal', 377.0)
# ('rapper', 373.0)
# ('treiter', 371.5)
# ('verder', 237.6)
# ('overslaan', 235.75)
# ('jeroen', 202.42857142857142)
# ('paulus', 190.0)
# ('jeugdhulp', 186.5)
# ('zoeken', 179.3)
# ('gaan', 168.2)
# ('tomaatnet', 156.0)
# ('lempens', 154.0)
# ('boshoven', 145.0)
# ('fatima', 143.0)
# ('leden', 139.9)
# ('risse', 137.0)
# ('oirschot', 134.0)
# ('creative', 131.0)
# ('keent', 127.0)
# ('raad', 126.11111111111111)
# ('wethouder', 122.0)
# ('geld', 121.6)
# ('onze', 119.3)
# ('textgeen', 117.0)
# ('wijkdossier', 116.0)
# ('afdelingen', 113.6)
# ('voorstel', 111.55555555555556)
# ('voorstellen', 111.0)
# ('leuken', 110.0)
# ('moesel', 107.0)
# ('inhoud', 104.9)
# ('opinie', 101.875)
# ('toekomst', 99.88888888888889)
# ('limburg', 96.44444444444444)
# ('bent', 96.3)
# ('optimisme', 94.5)
# ('stemt', 94.5)
# ('wis', 92.0)
# ('nodig', 92.0)
# ('mensen', 91.1)
# ('stellen', 88.7)
# ('overzicht', 87.0)
# ('maatregelen', 86.4)
# ('paulusjansen', 85.0)
# ('oplopenddatum', 84.0)
# ('hoofdmenuwij', 84.0)
# ('aflopend', 84.0)
# ('weertdegekste', 78.0)
# ('verkoop', 76.9)
# ('beschikbaar', 76.7)
# ('partijraad', 76.33333333333333)
# ('veolia', 76.0)
# ('bouwvereniging', 76.0)
# ('pvda', 72.33333333333333)
# ('biest', 72.0)
# ('kms', 71.66666666666667)
# ('vvd', 70.0)
# ('dossier', 67.25)
# ('waar', 66.6)
# ('following', 63.5)
# ('marijnissen', 63.0)
# ('rood', 63.0)
# ('college', 62.888888888888886)
# ('cda', 62.111111111111114)
# ('meertje', 62.0)
# ('ringbaan', 62.0)
# ('roermondseweg', 61.0)
# ('zie', 59.4)
# ('gaat', 58.5)
# ('hoof', 58.0)
# ('wel', 57.7)
# ('lokaal', 57.1)
# ('name', 55.9)
# ('gemeenteraad', 55.111111111111114)
# ('gymzaal', 55.0)
# ('bewoners', 54.77777777777778)
# ('moeselpeel', 54.0)
# ('bosuil', 53.5)
# ('wozoco', 53.0)
# ('regiofonds', 53.0)
# ('bospop', 52.0)
# ('graswinkel', 52.0)
# ('egging', 52.0)
# ('anders', 51.6)
# ('prevoo', 51.0)
# ('beatrixlaan', 49.0)
# ('dicaprio', 48.0)
# ('enck', 48.0)
# ('joseflaan', 47.0)
# ('zalencomplex', 47.0)
# ('flyert', 46.0)
# ('klimaatfilm', 46.0)

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2017, 4, 3, 21, 28, 51, 647517)

# %%
t = datetime.datetime.now()
datetime.datetime.now() - t
# Out:
# datetime.timedelta(0, 0, 122)

# %%
import getTermsImproved
import operator
import datetime
########
# Have to modify that 
# Should have incremental ints as keys as party names
# which are same as filenames as values
partyNums = {0: "50p", 1: "cda", 2: "cu", 3:"d66", 4:"gl", 5:"pvda", 6:"pvdd", 7:"pvv", 8:"sgp", 9:"sp", 10:"vvd"}
########
########


allTerms = {}
idfs = {}


# Loop over every party
# Return a nested dict 
# Outer dict k: int, v: dict
# Inner dict k: term, v: frequency
for x in xrange(1):
    print "Started " + str(partyNums[x]) + " " + str(datetime.datetime.now())
    allTerms[x] = getTermsImproved.getTerms2("/Users/user/Delft/IR/project/crawl/tutorial/res/1100/" + partyNums[x]+'.json')
    
    # Save all idfs into a dict of dicts
    # Outer dict k: int, v: dict
    # Inner dict k: term, v: present or not
    idfs[x] = {}
#     print len(allTerms[0])
    print "Imported " + str(partyNums[x])
    print datetime.datetime.now()
# Out:
# Started 50p 2017-04-03 23:46:29.752984
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-46-2f060336b434> in <module>()
#      21 for x in xrange(1):
#      22     print "Started " + str(partyNums[x]) + " " + str(datetime.datetime.now())
# ---> 23     allTerms[x] = getTermsImproved.getTerms2("/Users/user/Delft/IR/project/crawl/tutorial/res/1100/" + partyNums[x]+'.json')
#      24
#      25     # Save all idfs into a dict of dicts
#
# AttributeError: 'module' object has no attribute 'getTerms2'

# %%
import Beautifulsoup4 as bs
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-26-8d4f88f2362c> in <module>()
# ----> 1 import Beautifulsoup4 as bs
#
# ImportError: No module named Beautifulsoup4

# %%
html = """
    <div class="post-text" itemprop="description">
    
    <p>I would like to have all the text visible from a website, after the HTML is rendered. I'm working in Python with Scrapy framework.
 With <code>xpath('//body//text()')</code> I'm able to get it, but with the HTML tags, and I only want the text. Any solution for this? Thanks !</p>
 
     </div>"""

# %%
from bs4 import BeautifulSoup
# html = "https://www.sp.nl/"
soup = BeautifulSoup(html)
print soup.get_text().strip()
# Out:
# I would like to have all the text visible from a website, after the HTML is rendered. I'm working in Python with Scrapy framework.
#  With xpath('//body//text()') I'm able to get it, but with the HTML tags, and I only want the text. Any solution for this? Thanks !
